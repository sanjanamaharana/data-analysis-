# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanamaharana/data-analysis-/blob/main/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1
# Write a Python program to accept a student's name and display it in uppercase

name = input("Enter student name: ")
print("Uppercase Name:", name.upper())
# Out:
# Uppercase Name: SASD

# %%
# Q2
# City Name Operations

city = input("Enter city name: ")

print("Original Name:", city)
print("Uppercase:", city.upper())
print("Lowercase:", city.lower())
print("Title Case:", city.title())

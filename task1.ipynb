# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanamaharana/data-analysis-/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1
# Write a Python program to accept a student's name and display it in uppercase

name = input("Enter student name: ")
print("Uppercase Name:", name.upper())
# Out:
# Uppercase Name: SASD

# %%
# Q2
# City Name Operations

city = input("Enter city name: ")

print("Original Name:", city)
print("Uppercase:", city.upper())
print("Lowercase:", city.lower())
print("Title Case:", city.title())

# %%
# Q3.

# Write a Python program to accept a string and display its total length.
text = input("Enter a string: ")
print("Total length:", len(text))

# %%
# Q4.

# Write a Python program to accept a string and display:
# First Character
# Last Character
text = input("Enter a string: ")
print("First Character:", text[0])
print("Last Character:", text[-1])

# %%
# Q5.

# Write a Python program to count the number of times the letter 'a' appears in a given string.

text = input("Enter a string: ")
count = text.lower().count('a')
print("Letter 'a' appears", count, "times")

# %%
# Q6.

# Write a Python program to replace the word "Python" with "AI" in a given sentence.

sentence = input("Enter a sentence: ")
new_sentence = sentence.replace("Python", "AI")
print(new_sentence)

# %%
# Q7.

# Write a Python program to check whether an email address ends with @gmail.com.

email = input("Enter email: ")
if email.endswith("@gmail.com"):
    print("Valid Gmail address")
else:
    print("Not a Gmail address")

# %%
# Q8.
# Write a Python program to check whether a given input contains only digits

data = input("Enter something: ")
if data.isdigit():
    print("Contains only digits")
else:
    print("Contains other characters too")

# %%
# Q9.

# Write a Python program to check whether a given input contains only alphabets.

data = input("Enter something: ")
if data.isalpha():
    print("Contains only alphabets")
else:
    print("Contains other characters too")

# %%
# Q10.

# Write a Python program to split the following string into a list:

# Apple,Mango,Banana,Orange

fruits = "Apple,Mango,Banana,Orange"
fruit_list = fruits.split(",")
print(fruit_list)

# %%
# Q11.

# Write a Python program to check whether a person is eligible to vote or not.
# Condition:
# Age ≥ 18 → Eligible
# Otherwise → Not Eligible

age = int(input("Enter age: "))
if age >= 18:
    print("Eligible to vote")
else:
    print("Not Eligible")

# %%
# Q12.

# Write a Python program to check whether a number is:
# Positive
# Negative
# Zero

num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
# Q13.

# Write a Python program to find the greater number between two numbers.

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
if a > b:
    print("Greater number:", a)
elif b > a:
    print("Greater number:", b)
else:
    print("Both are equal")

# %%
# Q14.

# Write a Python program to assign grades based on marks.

# Marks	Grade

# 90 – 100	A
# 75 – 89	B
# 50 – 74	C
# Below 50	Fail

marks = float(input("Enter marks: "))
if 90 <= marks <= 100:
    print("Grade: A")
elif 75 <= marks <= 89:
    print("Grade: B")
elif 50 <= marks <= 74:
    print("Grade: C")
elif 0 <= marks < 50:
    print("Grade: Fail")
else:
    print("Invalid marks")

# %%
# Q15.

# Write a Python program to check whether a number is Even or Odd.

num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
# Q16.

# Write a Python program to check whether a password is strong or weak.
# Condition:
# Password length ≥ 8 → Strong Password
# Otherwise → Weak Password

password = input("Enter password: ")
if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")

# %%
# Q17.

# Write a Python program to check whether a given year is a Leap Year or not.

year = int(input("Enter year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100!= 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %%
# Q18.

# Write a Python program to find the largest among three numbers.

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)

# %%
# Q19.

# Write a Python program to validate login credentials.
# Condition:
# Username = admin
# Password = 1234

# Display:
# Login Successful
# Invalid Credentials

username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")

# %%
# Q20.

# Write a Python program to create a Simple Calculator.
# The program should:
# Accept two numbers from the user.
# Accept an operator (+, -, *, /).
# Perform the selected operation and display the result.

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print("Result:", num1 + num2)
elif op == "-":
    print("Result:", num1 - num2)
elif op == "*":
    print("Result:", num1 * num2)
elif op == "/":
    if num2!= 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Cannot divide by zero")
else:
    print("Invalid operator")
